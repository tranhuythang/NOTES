# %% [markdown]
# # Minimax Algorithm:
# # Breadth First
# # Best first search:
# ***Breadth First Search, Depth First Search, Dijkstra, Uniform cost search, A* search are special cases of Best First Search***
# ***The difference among those algorithms is: terminating condition and what notes are explored.***
# ***
# a)
#
# – BFS is best-first with f(n) = depth(n)
#
# – DFS is best-first with f(n) = −depth(n) or f(n) = 1/depth(n)
#
# – Uniform cost is best-first with f(n) = g(n)
#
# b) UCS is A* with h(n) = 0
# ***
#
# Input: startNode, function P(node) to calculate the priority of node and P() is usually the path_cost
# Output: path to finishNodeBestFirstSearch:
#
# Best First Search:
#
# priorityqueue PQ = []
# visited = []
# Trace = []
# push (startNode, F(startNode)) into PQ
#
# while PQ is not empty:
#     top = PQ.pop()
#     add top to visited
#     if top == targetNode:
#         break
#     for each child of top:
#         if child == targetNode:
#             add (targetNode:top) to Trace
#             break the two loop
#         if child is not in visited:
#             push (child, F(node)) into PQ
#
#
# Uniform Cost Search
# priorityqueue Frontier = [(0,startNode)]
# path_cost = float("inf")
# visited = []
# while Frontier is not empty:
#     top = PQ.pop()
#     if top[0] >= path_cost:
#         break
#     for each child of top:
#         startNode_to_child = top[0] + edge_length(top, child)
#         if child is not in visited
#             push (startNode_to_child, child) into Frontier
#         else:
#             if startNode_to_child <= visited[child]
#                 visited[child] = startNode_to_child
#         if child == targetNode:
#             if startNode_to_child < path_cost:
#                 path_cost = startNode_to_child
#
#         add top to Visited
#         for each child
